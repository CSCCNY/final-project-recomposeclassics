# %%
#Mounting google and authenticating
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
#!ls /mydrive
# Out:
# Mounted at /content/gdrive

# %%
# !cp /mydrive/music\ project/X_spec.pickle ./
# !cp /mydrive/music\ project/y_spec.pickle ./

# %%
#LOADING DATA
import pickle 
pickle_off = open("X_spec.pickle", 'rb')
X_spec = pickle.load(pickle_off)

pickle_off = open("y_spec.pickle", 'rb')
y_spec = pickle.load(pickle_off)

# %%
y_spec.shape
# Out:
# (1431, 300, 128)

# %%
#RESHAPING
X_spec_ = X_spec.reshape(1431, 300, 128, 1)
y_spec_ = y_spec.reshape(1431, 300, 128, 1)

# %%
#SPLITTING TO TRAIN AND TEST
print(X_spec_.shape)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_spec_, y_spec_, test_size=0.1, random_state=42)
print(X_train.shape, X_test.shape)
# Out:
# (1431, 300, 128, 1)
# (1287, 300, 128, 1) (144, 300, 128, 1)

# %%
#for regression
X_regr = X_train.reshape(-1,1)
y_regr = y_train.reshape(-1,1)

X_val_r = X_train.reshape(-1,1)
y_val_r = y_test.reshape(-1,1)
#y_val_reshape.reshape(1, len(y_val_reshape),1)

# %%
#Using Random Forest
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=8, random_state=0)
regr.fit(X_regr, y_regr)

#print(regr.predict([[0, 0, 0, 0]]))

# %%
#R square
regr.score(X_regr, y_regr)

# %%
#Using regressor sequential
from tensorflow import keras
from tensorflow.keras import layers

horsepower_normalizer = preprocessing.Normalization(input_shape=[1,])
horsepower_normalizer.adapt(X_spec_
                            )

horsepower_model = tf.keras.Sequential([
    horsepower_normalizer,
    layers.Dense(units=1)
])

# %%
import tensorflow as tf
horsepower_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error', metrics=[tf.keras.metrics.MeanSquaredError()])

history = horsepower_model.fit(
    X_spec_, y_spec_,
    epochs=5,
    # suppress logging
    #verbose=0,
    # Calculate validation results on 10% of the training data
    validation_split = 0.1)
# Out:
# Epoch 1/5
# 76032/76032 [==============================] - 117s 2ms/step - loss: 10.2469 - mean_squared_error: 186.6453 - val_loss: 8.7888 - val_mean_squared_error: 126.8809
# Epoch 2/5
# 76032/76032 [==============================] - 116s 2ms/step - loss: 9.7955 - mean_squared_error: 165.4883 - val_loss: 8.7916 - val_mean_squared_error: 126.2527
# Epoch 3/5
# 76032/76032 [==============================] - 117s 2ms/step - loss: 9.7876 - mean_squared_error: 165.1230 - val_loss: 8.8311 - val_mean_squared_error: 127.3049
# Epoch 4/5
# 76032/76032 [==============================] - 117s 2ms/step - loss: 9.8009 - mean_squared_error: 165.6078 - val_loss: 8.7863 - val_mean_squared_error: 126.4755
# Epoch 5/5
# 76032/76032 [==============================] - 117s 2ms/step - loss: 9.7931 - mean_squared_error: 165.4911 - val_loss: 8.7642 - val_mean_squared_error: 125.6438

# %%
import matplotlib.pyplot as plt

Epochs = 5
train_loss = history.history['loss']
train_accuracy = history.history['val_loss']

epochs = range(Epochs)

plt.figure()
plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, train_accuracy, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([5, 12])
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

Epochs = 5
train_loss = history.history['mean_squared_error']
train_accuracy = history.history['val_mean_squared_error']

epochs = range(Epochs)

plt.figure()
plt.plot(epochs, train_loss, 'r', label='Training mse')
plt.plot(epochs, train_accuracy, 'bo', label='Validation mse')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([100, 190])
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
#from tensorflow.keras.layers import Lambda, RepeatVector, Reshape
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import Concatenate 
from tensorflow.keras.optimizers import Adam

# %%
#AUTOENCODING
from tensorflow import keras
from tensorflow.keras import layers



encoder_input = keras.Input(shape=(440, 128, 1), name="original_img")
x = layers.Conv2D(16, 3, activation="relu")(encoder_input)
x = tf.keras.layers.Conv2D(32, 3, activation="relu")(x)
x = layers.MaxPooling2D(3)(x)
x = layers.Conv2D(32, 3, activation="relu")(x)
x = layers.Conv2D(16, 3, activation="relu")(x)
encoder_output = layers.GlobalMaxPooling2D()(x)

encoder = keras.Model(encoder_input, encoder_output, name="encoder")
encoder.summary()

decoder_input = keras.Input(shape=(16,), name="encoded_img")
x = layers.Reshape((4, 4, 1))(decoder_input)
x = layers.Conv2DTranspose(16, 3, activation="relu")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu")(x)
x = layers.UpSampling2D((54,15))(x)
x = layers.Conv2DTranspose(32, 5, activation="relu")(x)
decoder_output = layers.Conv2DTranspose(1, 5)(x)

decoder = keras.Model(decoder_input, decoder_output, name="decoder")
decoder.summary()

autoencoder_input = keras.Input(shape=(440, 128, 1), name="img")
encoded_img = encoder(autoencoder_input)
decoded_img = decoder(encoded_img)
autoencoder = keras.Model(autoencoder_input, decoded_img, name="autoencoder")
autoencoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# original_img (InputLayer)    [(None, 440, 128, 1)]     0
# _________________________________________________________________
# conv2d_105 (Conv2D)          (None, 438, 126, 16)      160
# _________________________________________________________________
# conv2d_106 (Conv2D)          (None, 436, 124, 32)      4640
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 145, 41, 32)       0
# _________________________________________________________________
# conv2d_107 (Conv2D)          (None, 143, 39, 32)       9248
# _________________________________________________________________
# conv2d_108 (Conv2D)          (None, 141, 37, 16)       4624
# _________________________________________________________________
# global_max_pooling2d_16 (Glo (None, 16)                0
# =================================================================
# Total params: 18,672
# Trainable params: 18,672
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_img (InputLayer)     [(None, 16)]              0
# _________________________________________________________________
# reshape_16 (Reshape)         (None, 4, 4, 1)           0
# _________________________________________________________________
# conv2d_transpose_68 (Conv2DT (None, 6, 6, 16)          160
# _________________________________________________________________
# conv2d_transpose_69 (Conv2DT (None, 8, 8, 32)          4640
# _________________________________________________________________
# up_sampling2d_16 (UpSampling (None, 432, 120, 32)      0
# _________________________________________________________________
# conv2d_transpose_70 (Conv2DT (None, 436, 124, 32)      25632
# _________________________________________________________________
# conv2d_transpose_71 (Conv2DT (None, 440, 128, 1)       801
# =================================================================
# Total params: 31,233
# Trainable params: 31,233
# Non-trainable params: 0
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             [(None, 440, 128, 1)]     0
# _________________________________________________________________
# encoder (Functional)         (None, 16)                18672
# _________________________________________________________________
# decoder (Functional)         (None, 440, 128, 1)       31233
# =================================================================
# Total params: 49,905
# Trainable params: 49,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer=Adam(), loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()])

# %%
history = autoencoder.fit(X_train, y_train, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 0s 138ms/step - loss: 158.6112 - mean_squared_error: 158.6112 - val_loss: 113.9731 - val_mean_squared_error: 113.9731
# Epoch 2/50
# 2/2 [==============================] - 0s 73ms/step - loss: 148.0618 - mean_squared_error: 148.0618 - val_loss: 114.2196 - val_mean_squared_error: 114.2196
# Epoch 3/50
# 2/2 [==============================] - 0s 80ms/step - loss: 140.7964 - mean_squared_error: 140.7964 - val_loss: 141.5448 - val_mean_squared_error: 141.5448
# Epoch 4/50
# 2/2 [==============================] - 0s 71ms/step - loss: 163.2144 - mean_squared_error: 163.2144 - val_loss: 144.7345 - val_mean_squared_error: 144.7345
# Epoch 5/50
# 2/2 [==============================] - 0s 74ms/step - loss: 162.1255 - mean_squared_error: 162.1255 - val_loss: 109.7072 - val_mean_squared_error: 109.7072
# Epoch 6/50
# 2/2 [==============================] - 0s 72ms/step - loss: 141.9182 - mean_squared_error: 141.9182 - val_loss: 120.6839 - val_mean_squared_error: 120.6839
# Epoch 7/50
# 2/2 [==============================] - 0s 76ms/step - loss: 152.3775 - mean_squared_error: 152.3775 - val_loss: 121.2858 - val_mean_squared_error: 121.2858
# Epoch 8/50
# 2/2 [==============================] - 0s 79ms/step - loss: 145.9977 - mean_squared_error: 145.9977 - val_loss: 145.4189 - val_mean_squared_error: 145.4189
# Epoch 9/50
# 2/2 [==============================] - 0s 74ms/step - loss: 160.6684 - mean_squared_error: 160.6684 - val_loss: 104.6369 - val_mean_squared_error: 104.6369
# Epoch 10/50
# 2/2 [==============================] - 0s 73ms/step - loss: 133.6332 - mean_squared_error: 133.6332 - val_loss: 131.4404 - val_mean_squared_error: 131.4404
# Epoch 11/50
# 2/2 [==============================] - 0s 75ms/step - loss: 166.7582 - mean_squared_error: 166.7582 - val_loss: 109.0628 - val_mean_squared_error: 109.0628
# Epoch 12/50
# 2/2 [==============================] - 0s 74ms/step - loss: 138.1268 - mean_squared_error: 138.1268 - val_loss: 140.4755 - val_mean_squared_error: 140.4755
# Epoch 13/50
# 2/2 [==============================] - 0s 77ms/step - loss: 160.4041 - mean_squared_error: 160.4041 - val_loss: 105.7696 - val_mean_squared_error: 105.7696
# Epoch 14/50
# 2/2 [==============================] - 0s 73ms/step - loss: 129.2370 - mean_squared_error: 129.2370 - val_loss: 108.9528 - val_mean_squared_error: 108.9528
# Epoch 15/50
# 2/2 [==============================] - 0s 74ms/step - loss: 140.1530 - mean_squared_error: 140.1529 - val_loss: 106.0425 - val_mean_squared_error: 106.0425
# Epoch 16/50
# 2/2 [==============================] - 0s 74ms/step - loss: 132.5624 - mean_squared_error: 132.5624 - val_loss: 111.4401 - val_mean_squared_error: 111.4401
# Epoch 17/50
# 2/2 [==============================] - 0s 70ms/step - loss: 130.2890 - mean_squared_error: 130.2890 - val_loss: 107.8690 - val_mean_squared_error: 107.8690
# Epoch 18/50
# 2/2 [==============================] - 0s 74ms/step - loss: 128.6892 - mean_squared_error: 128.6892 - val_loss: 106.2370 - val_mean_squared_error: 106.2370
# Epoch 19/50
# 2/2 [==============================] - 0s 71ms/step - loss: 129.7223 - mean_squared_error: 129.7223 - val_loss: 107.5369 - val_mean_squared_error: 107.5369
# Epoch 20/50
# 2/2 [==============================] - 0s 70ms/step - loss: 127.6325 - mean_squared_error: 127.6325 - val_loss: 109.0505 - val_mean_squared_error: 109.0505
# Epoch 21/50
# 2/2 [==============================] - 0s 71ms/step - loss: 127.6039 - mean_squared_error: 127.6039 - val_loss: 104.1013 - val_mean_squared_error: 104.1013
# Epoch 22/50
# 2/2 [==============================] - 0s 71ms/step - loss: 125.7191 - mean_squared_error: 125.7191 - val_loss: 103.2761 - val_mean_squared_error: 103.2761
# Epoch 23/50
# 2/2 [==============================] - 0s 73ms/step - loss: 126.0656 - mean_squared_error: 126.0656 - val_loss: 102.1814 - val_mean_squared_error: 102.1814
# Epoch 24/50
# 2/2 [==============================] - 0s 76ms/step - loss: 125.0155 - mean_squared_error: 125.0155 - val_loss: 101.8602 - val_mean_squared_error: 101.8602
# Epoch 25/50
# 2/2 [==============================] - 0s 72ms/step - loss: 124.6793 - mean_squared_error: 124.6793 - val_loss: 104.3061 - val_mean_squared_error: 104.3061
# Epoch 26/50
# 2/2 [==============================] - 0s 74ms/step - loss: 123.7739 - mean_squared_error: 123.7739 - val_loss: 105.6602 - val_mean_squared_error: 105.6602
# Epoch 27/50
# 2/2 [==============================] - 0s 75ms/step - loss: 124.5534 - mean_squared_error: 124.5534 - val_loss: 100.4709 - val_mean_squared_error: 100.4709
# Epoch 28/50
# 2/2 [==============================] - 0s 74ms/step - loss: 123.9247 - mean_squared_error: 123.9247 - val_loss: 104.0506 - val_mean_squared_error: 104.0506
# Epoch 29/50
# 2/2 [==============================] - 0s 73ms/step - loss: 124.1240 - mean_squared_error: 124.1240 - val_loss: 110.6206 - val_mean_squared_error: 110.6206
# Epoch 30/50
# 2/2 [==============================] - 0s 71ms/step - loss: 125.7716 - mean_squared_error: 125.7716 - val_loss: 101.5354 - val_mean_squared_error: 101.5354
# Epoch 31/50
# 2/2 [==============================] - 0s 70ms/step - loss: 124.7348 - mean_squared_error: 124.7348 - val_loss: 101.8546 - val_mean_squared_error: 101.8546
# Epoch 32/50
# 2/2 [==============================] - 0s 71ms/step - loss: 123.9417 - mean_squared_error: 123.9417 - val_loss: 107.1669 - val_mean_squared_error: 107.1669
# Epoch 33/50
# 2/2 [==============================] - 0s 75ms/step - loss: 123.8447 - mean_squared_error: 123.8447 - val_loss: 102.6522 - val_mean_squared_error: 102.6522
# Epoch 34/50
# 2/2 [==============================] - 0s 74ms/step - loss: 121.4757 - mean_squared_error: 121.4757 - val_loss: 103.1509 - val_mean_squared_error: 103.1509
# Epoch 35/50
# 2/2 [==============================] - 0s 75ms/step - loss: 131.1813 - mean_squared_error: 131.1813 - val_loss: 105.0030 - val_mean_squared_error: 105.0030
# Epoch 36/50
# 2/2 [==============================] - 0s 74ms/step - loss: 129.0558 - mean_squared_error: 129.0558 - val_loss: 114.4776 - val_mean_squared_error: 114.4776
# Epoch 37/50
# 2/2 [==============================] - 0s 73ms/step - loss: 130.0315 - mean_squared_error: 130.0315 - val_loss: 116.7405 - val_mean_squared_error: 116.7405
# Epoch 38/50
# 2/2 [==============================] - 0s 71ms/step - loss: 129.2246 - mean_squared_error: 129.2246 - val_loss: 101.0124 - val_mean_squared_error: 101.0124
# Epoch 39/50
# 2/2 [==============================] - 0s 71ms/step - loss: 124.9936 - mean_squared_error: 124.9936 - val_loss: 109.7193 - val_mean_squared_error: 109.7194
# Epoch 40/50
# 2/2 [==============================] - 0s 73ms/step - loss: 135.0341 - mean_squared_error: 135.0341 - val_loss: 108.3337 - val_mean_squared_error: 108.3337
# Epoch 41/50
# 2/2 [==============================] - 0s 71ms/step - loss: 124.5257 - mean_squared_error: 124.5256 - val_loss: 135.7908 - val_mean_squared_error: 135.7908
# Epoch 42/50
# 2/2 [==============================] - 0s 70ms/step - loss: 142.7800 - mean_squared_error: 142.7800 - val_loss: 100.2086 - val_mean_squared_error: 100.2086
# Epoch 43/50
# 2/2 [==============================] - 0s 75ms/step - loss: 123.6791 - mean_squared_error: 123.6791 - val_loss: 111.4296 - val_mean_squared_error: 111.4296
# Epoch 44/50
# 2/2 [==============================] - 0s 72ms/step - loss: 134.8527 - mean_squared_error: 134.8527 - val_loss: 110.8046 - val_mean_squared_error: 110.8046
# Epoch 45/50
# 2/2 [==============================] - 0s 74ms/step - loss: 123.9001 - mean_squared_error: 123.9001 - val_loss: 122.6495 - val_mean_squared_error: 122.6495
# Epoch 46/50
# 2/2 [==============================] - 0s 71ms/step - loss: 131.4264 - mean_squared_error: 131.4264 - val_loss: 102.8850 - val_mean_squared_error: 102.8850
# Epoch 47/50
# 2/2 [==============================] - 0s 73ms/step - loss: 118.1292 - mean_squared_error: 118.1292 - val_loss: 106.0949 - val_mean_squared_error: 106.0949
# Epoch 48/50
# 2/2 [==============================] - 0s 72ms/step - loss: 124.1787 - mean_squared_error: 124.1787 - val_loss: 105.4828 - val_mean_squared_error: 105.4828
# Epoch 49/50
# 2/2 [==============================] - 0s 71ms/step - loss: 119.2061 - mean_squared_error: 119.2061 - val_loss: 117.5527 - val_mean_squared_error: 117.5527
# Epoch 50/50
# 2/2 [==============================] - 0s 68ms/step - loss: 126.9669 - mean_squared_error: 126.9669 - val_loss: 100.7358 - val_mean_squared_error: 100.7358

# %%
#SHOWING RESULTS OF AUTOENCODING
import matplotlib.pyplot as plt

Epochs = 50
train_loss = history.history['loss']
train_accuracy = history.history['val_loss']

epochs = range(Epochs)

plt.figure()
plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, train_accuracy, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([100, 190])
plt.legend()
plt.show()

# %%
pred_mask = autoencoder.predict(X_test)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ffb09f0ba70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
pred_mask = pred_mask.reshape(5,440,128)
X_test = X_test.reshape(5,440,128)

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
import librosa
import librosa.display

fig = plt.Figure()
canvas = FigureCanvas(fig)
ax = fig.add_subplot(111)
p = librosa.display.specshow(X_test[0], ax=ax, y_axis='mel', fmax=8000, x_axis='time')
fig.savefig('spec1.png')

# %%
librosa.display.specshow(X_test[0], y_axis='mel', fmax=8000, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('test')
plt.show()

# %%
librosa.display.specshow(pred_mask[0], y_axis='mel', fmax=8000, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Predicted')
plt.show()

# %%
print(len(np.unique(X_test[0])))
print(len(np.unique(pred_mask[0])))
# Out:
# 50640
# 9653

# %%
#AUTOENCODING
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

x = tf.keras.layers.Input((300, 128, 1))
x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=(2, 2), padding='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=(2, 2), padding='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=(2, 2), padding='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=(1, 1), padding='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, strides=(2, 2), padding='same', activation='relu')(x)
x.shape

encoder_input = keras.Input(shape=(440, 128, 1), name="original_img")
x = layers.Conv2D(256, 3, activation="relu")(encoder_input)
x = tf.keras.layers.Conv2D(256, 3, activation="relu")(x)
x = layers.MaxPooling2D(3)(x)
x = layers.Conv2D(256, 3, activation="relu")(x)
x = layers.Conv2D(64, 3, activation="relu")(x)
encoder_output = layers.GlobalMaxPooling2D()(x)

encoder = keras.Model(encoder_input, encoder_output, name="encoder")
encoder.summary()

decoder_input = keras.Input(shape=(64,), name="encoded_img")
x = layers.Reshape((16, 4, 1))(decoder_input)
x = layers.Conv2DTranspose(256, 3, activation="relu")(x)
x = layers.Conv2DTranspose(256, 3, activation="relu")(x)
x = layers.UpSampling2D((22, 16))(x)
x = layers.Conv2DTranspose(256, 3, padding='same' ,activation="relu")(x)
decoder_output = layers.Conv2DTranspose(1, 3, padding='same')(x)

decoder = keras.Model(decoder_input, decoder_output, name="decoder")
decoder.summary()

autoencoder_input = keras.Input(shape=(440, 128, 1), name="img")
encoded_img = encoder(autoencoder_input)
decoded_img = decoder(encoded_img)
autoencoder = keras.Model(autoencoder_input, decoded_img, name="autoencoder")
autoencoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# original_img (InputLayer)    [(None, 440, 128, 1)]     0
# _________________________________________________________________
# conv2d_213 (Conv2D)          (None, 438, 126, 256)     2560
# _________________________________________________________________
# conv2d_214 (Conv2D)          (None, 436, 124, 256)     590080
# _________________________________________________________________
# max_pooling2d_53 (MaxPooling (None, 145, 41, 256)      0
# _________________________________________________________________
# conv2d_215 (Conv2D)          (None, 143, 39, 256)      590080
# _________________________________________________________________
# conv2d_216 (Conv2D)          (None, 141, 37, 64)       147520
# _________________________________________________________________
# global_max_pooling2d_53 (Glo (None, 64)                0
# =================================================================
# Total params: 1,330,240
# Trainable params: 1,330,240
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_img (InputLayer)     [(None, 64)]              0
# _________________________________________________________________
# reshape_53 (Reshape)         (None, 16, 4, 1)          0
# _________________________________________________________________
# conv2d_transpose_209 (Conv2D (None, 18, 6, 256)        2560
# _________________________________________________________________
# conv2d_transpose_210 (Conv2D (None, 20, 8, 256)        590080
# _________________________________________________________________
# up_sampling2d_53 (UpSampling (None, 440, 128, 256)     0
# _________________________________________________________________
# conv2d_transpose_211 (Conv2D (None, 440, 128, 256)     590080
# _________________________________________________________________
# conv2d_transpose_212 (Conv2D (None, 440, 128, 1)       2305
# =================================================================
# Total params: 1,185,025
# Trainable params: 1,185,025
# Non-trainable params: 0
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             [(None, 440, 128, 1)]     0
# _________________________________________________________________
# encoder (Functional)         (None, 64)                1330240
# _________________________________________________________________
# decoder (Functional)         (None, 440, 128, 1)       1185025
# =================================================================
# Total params: 2,515,265
# Trainable params: 2,515,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer=Adam(), loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()])

# %%
history = autoencoder.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 587ms/step - loss: 115.7585 - mean_squared_error: 115.7585 - val_loss: 137.7803 - val_mean_squared_error: 137.7803
# Epoch 2/50
# 2/2 [==============================] - 3s 556ms/step - loss: 114.4720 - mean_squared_error: 114.4720 - val_loss: 130.8078 - val_mean_squared_error: 130.8078
# Epoch 3/50
# 2/2 [==============================] - 3s 559ms/step - loss: 110.6226 - mean_squared_error: 110.6226 - val_loss: 124.0924 - val_mean_squared_error: 124.0924
# Epoch 4/50
# 2/2 [==============================] - 3s 565ms/step - loss: 116.4668 - mean_squared_error: 116.4668 - val_loss: 118.9035 - val_mean_squared_error: 118.9035
# Epoch 5/50
# 2/2 [==============================] - 3s 558ms/step - loss: 107.1085 - mean_squared_error: 107.1085 - val_loss: 136.1195 - val_mean_squared_error: 136.1195
# Epoch 6/50
# 2/2 [==============================] - 3s 564ms/step - loss: 117.4301 - mean_squared_error: 117.4301 - val_loss: 123.6539 - val_mean_squared_error: 123.6539
# Epoch 7/50
# 2/2 [==============================] - 3s 568ms/step - loss: 110.0678 - mean_squared_error: 110.0678 - val_loss: 125.8784 - val_mean_squared_error: 125.8784
# Epoch 8/50
# 2/2 [==============================] - 3s 571ms/step - loss: 119.4678 - mean_squared_error: 119.4678 - val_loss: 120.0453 - val_mean_squared_error: 120.0453
# Epoch 9/50
# 2/2 [==============================] - 3s 575ms/step - loss: 114.4768 - mean_squared_error: 114.4768 - val_loss: 114.9663 - val_mean_squared_error: 114.9663
# Epoch 10/50
# 2/2 [==============================] - 3s 577ms/step - loss: 107.9123 - mean_squared_error: 107.9123 - val_loss: 127.5080 - val_mean_squared_error: 127.5080
# Epoch 11/50
# 2/2 [==============================] - 3s 575ms/step - loss: 115.4736 - mean_squared_error: 115.4736 - val_loss: 139.8144 - val_mean_squared_error: 139.8144
# Epoch 12/50
# 2/2 [==============================] - 3s 591ms/step - loss: 119.4968 - mean_squared_error: 119.4968 - val_loss: 136.2774 - val_mean_squared_error: 136.2774
# Epoch 13/50
# 2/2 [==============================] - 3s 581ms/step - loss: 109.6574 - mean_squared_error: 109.6574 - val_loss: 141.7647 - val_mean_squared_error: 141.7647
# Epoch 14/50
# 2/2 [==============================] - 3s 592ms/step - loss: 129.8411 - mean_squared_error: 129.8411 - val_loss: 122.4006 - val_mean_squared_error: 122.4006
# Epoch 15/50
# 2/2 [==============================] - 3s 588ms/step - loss: 112.6174 - mean_squared_error: 112.6174 - val_loss: 131.1232 - val_mean_squared_error: 131.1232
# Epoch 16/50
# 2/2 [==============================] - 3s 580ms/step - loss: 112.9582 - mean_squared_error: 112.9582 - val_loss: 122.4928 - val_mean_squared_error: 122.4928
# Epoch 17/50
# 2/2 [==============================] - 3s 577ms/step - loss: 105.9345 - mean_squared_error: 105.9344 - val_loss: 127.0837 - val_mean_squared_error: 127.0837
# Epoch 18/50
# 2/2 [==============================] - 3s 574ms/step - loss: 104.8043 - mean_squared_error: 104.8044 - val_loss: 137.3469 - val_mean_squared_error: 137.3469
# Epoch 19/50
# 2/2 [==============================] - 3s 573ms/step - loss: 108.6060 - mean_squared_error: 108.6060 - val_loss: 124.6117 - val_mean_squared_error: 124.6117
# Epoch 20/50
# 2/2 [==============================] - 3s 566ms/step - loss: 106.6470 - mean_squared_error: 106.6471 - val_loss: 125.5100 - val_mean_squared_error: 125.5100
# Epoch 21/50
# 2/2 [==============================] - 3s 557ms/step - loss: 109.8025 - mean_squared_error: 109.8024 - val_loss: 132.6962 - val_mean_squared_error: 132.6962
# Epoch 22/50
# 2/2 [==============================] - 3s 565ms/step - loss: 110.3463 - mean_squared_error: 110.3463 - val_loss: 123.0608 - val_mean_squared_error: 123.0608
# Epoch 23/50
# 2/2 [==============================] - 3s 562ms/step - loss: 103.2862 - mean_squared_error: 103.2862 - val_loss: 127.8967 - val_mean_squared_error: 127.8967
# Epoch 24/50
# 2/2 [==============================] - 3s 557ms/step - loss: 108.7659 - mean_squared_error: 108.7659 - val_loss: 145.8791 - val_mean_squared_error: 145.8791
# Epoch 25/50
# 2/2 [==============================] - 3s 560ms/step - loss: 122.1256 - mean_squared_error: 122.1256 - val_loss: 125.1140 - val_mean_squared_error: 125.1140
# Epoch 26/50
# 2/2 [==============================] - 3s 553ms/step - loss: 109.7310 - mean_squared_error: 109.7310 - val_loss: 124.6428 - val_mean_squared_error: 124.6428
# Epoch 27/50
# 2/2 [==============================] - 3s 558ms/step - loss: 108.0306 - mean_squared_error: 108.0306 - val_loss: 136.1621 - val_mean_squared_error: 136.1621
# Epoch 28/50
# 2/2 [==============================] - 3s 561ms/step - loss: 112.3041 - mean_squared_error: 112.3041 - val_loss: 126.5018 - val_mean_squared_error: 126.5018
# Epoch 29/50
# 2/2 [==============================] - 3s 565ms/step - loss: 105.4663 - mean_squared_error: 105.4663 - val_loss: 123.8522 - val_mean_squared_error: 123.8522
# Epoch 30/50
# 2/2 [==============================] - 3s 556ms/step - loss: 104.5355 - mean_squared_error: 104.5355 - val_loss: 124.1207 - val_mean_squared_error: 124.1207
# Epoch 31/50
# 2/2 [==============================] - 3s 566ms/step - loss: 102.0179 - mean_squared_error: 102.0179 - val_loss: 121.6636 - val_mean_squared_error: 121.6636
# Epoch 32/50
# 2/2 [==============================] - 3s 560ms/step - loss: 103.1612 - mean_squared_error: 103.1612 - val_loss: 119.9181 - val_mean_squared_error: 119.9181
# Epoch 33/50
# 2/2 [==============================] - 3s 570ms/step - loss: 100.0403 - mean_squared_error: 100.0403 - val_loss: 125.8540 - val_mean_squared_error: 125.8540
# Epoch 34/50
# 2/2 [==============================] - 3s 579ms/step - loss: 100.6974 - mean_squared_error: 100.6974 - val_loss: 123.9971 - val_mean_squared_error: 123.9971
# Epoch 35/50
# 2/2 [==============================] - 3s 577ms/step - loss: 101.0087 - mean_squared_error: 101.0087 - val_loss: 123.9516 - val_mean_squared_error: 123.9516
# Epoch 36/50
# 2/2 [==============================] - 3s 571ms/step - loss: 101.8832 - mean_squared_error: 101.8833 - val_loss: 129.1302 - val_mean_squared_error: 129.1302
# Epoch 37/50
# 2/2 [==============================] - 3s 584ms/step - loss: 105.2062 - mean_squared_error: 105.2062 - val_loss: 131.5361 - val_mean_squared_error: 131.5361
# Epoch 38/50
# 2/2 [==============================] - 3s 579ms/step - loss: 103.7163 - mean_squared_error: 103.7163 - val_loss: 130.6323 - val_mean_squared_error: 130.6323
# Epoch 39/50
# 2/2 [==============================] - 3s 576ms/step - loss: 109.3270 - mean_squared_error: 109.3270 - val_loss: 123.9598 - val_mean_squared_error: 123.9598
# Epoch 40/50
# 2/2 [==============================] - 3s 585ms/step - loss: 99.5141 - mean_squared_error: 99.5141 - val_loss: 131.3461 - val_mean_squared_error: 131.3461
# Epoch 41/50
# 2/2 [==============================] - 3s 583ms/step - loss: 105.8967 - mean_squared_error: 105.8967 - val_loss: 119.8225 - val_mean_squared_error: 119.8225
# Epoch 42/50
# 2/2 [==============================] - 3s 579ms/step - loss: 99.6743 - mean_squared_error: 99.6743 - val_loss: 125.4554 - val_mean_squared_error: 125.4554
# Epoch 43/50
# 2/2 [==============================] - 3s 573ms/step - loss: 103.7312 - mean_squared_error: 103.7312 - val_loss: 122.9215 - val_mean_squared_error: 122.9215
# Epoch 44/50
# 2/2 [==============================] - 3s 574ms/step - loss: 97.0196 - mean_squared_error: 97.0196 - val_loss: 132.3607 - val_mean_squared_error: 132.3607
# Epoch 45/50
# 2/2 [==============================] - 3s 567ms/step - loss: 103.5002 - mean_squared_error: 103.5002 - val_loss: 118.9858 - val_mean_squared_error: 118.9858
# Epoch 46/50
# 2/2 [==============================] - 3s 569ms/step - loss: 97.7737 - mean_squared_error: 97.7737 - val_loss: 121.3906 - val_mean_squared_error: 121.3907
# Epoch 47/50
# 2/2 [==============================] - 3s 573ms/step - loss: 101.3976 - mean_squared_error: 101.3976 - val_loss: 122.9186 - val_mean_squared_error: 122.9186
# Epoch 48/50
# 2/2 [==============================] - 3s 564ms/step - loss: 96.5687 - mean_squared_error: 96.5687 - val_loss: 123.8122 - val_mean_squared_error: 123.8122
# Epoch 49/50
# 2/2 [==============================] - 3s 570ms/step - loss: 96.2748 - mean_squared_error: 96.2748 - val_loss: 127.2023 - val_mean_squared_error: 127.2023
# Epoch 50/50
# 2/2 [==============================] - 3s 565ms/step - loss: 97.7087 - mean_squared_error: 97.7087 - val_loss: 126.2815 - val_mean_squared_error: 126.2815

# %%
#SHOWING RESULTS OF AUTOENCODING Fist part
import matplotlib.pyplot as plt

Epochs = 50
train_loss = history.history['loss']
train_accuracy = history.history['val_loss']

epochs = range(Epochs)

plt.figure()
plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, train_accuracy, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([100, 190])
plt.legend()
plt.show()

# %%
#SHOWING RESULTS OF AUTOENCODING Fist part
import matplotlib.pyplot as plt

Epochs = 50
train_loss = history.history['loss']
train_accuracy = history.history['val_loss']

epochs = range(Epochs)

plt.figure()
plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, train_accuracy, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([100, 190])
plt.legend()
plt.show()

# %%
pred_mask = autoencoder.predict(X_test)
pred_mask = pred_mask.reshape(5,440,128)
y_test = y_test.reshape(5,440,128)

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display

fig, ax = plt.subplots(2)
a = librosa.display.specshow(y_test[0], y_axis='mel', fmax=8000, x_axis='time', ax=ax[0])
fig.colorbar(a, format='%+2.0f dB', ax=ax[0])
ax[0].set_title('test')
#ax[0].show()

b = librosa.display.specshow(pred_mask[0], y_axis='mel', fmax=8000, x_axis='time', ax=ax[1])
fig.colorbar(b, format='%+2.0f dB', ax=ax[1])
ax[1].set_title('Predicted')
#ax[1].show()
# Out:
# Text(0.5, 1.0, 'Predicted')

# %%
import scipy
from scipy.io.wavfile import write
import numpy as np


sr=22050

#First Approach audio conversion
audio_path = '/content/audio/test.wav'
wav = librosa.db_to_power(y_test[0], ref=1.0)
wav = librosa.feature.inverse.mel_to_audio (M=wav, hop_length=512, sr=sr)
#wav *= 32767 / max (0.01, np.max(np.abs(wav)))
#scipy.io.wavfile.write (audio_path, 16000, wav.astype(np.int16))
write (audio_path, sr, wav.astype(np.float32))

sr=22050

#First Approach audio conversion
audio_path = '/content/audio/predicted.wav'
wav = librosa.db_to_power(pred_mask[0], ref=1.0)
wav = librosa.feature.inverse.mel_to_audio (M=wav, hop_length=512, sr=sr)
#wav *= 32767 / max (0.01, np.max(np.abs(wav)))
#scipy.io.wavfile.write (audio_path, 16000, wav.astype(np.int16))
write (audio_path, sr, wav.astype(np.float32))

# %%
import matplotlib.pyplot as plt
y, sr = librosa.load('/content/audio/test.wav')
fig, ax = plt.subplots(nrows=2, sharex=True, sharey=True)
librosa.display.waveplot(y, sr=sr, ax=ax[0])
ax[0].set(title='Original Audio file')
ax[0].label_outer()

y, sr = librosa.load('/content/audio/predicted.wav')
librosa.display.waveplot(y, sr=sr, ax=ax[1])
ax[1].set(title='Predicted Audio')
ax[1].label_outer()

# %%
#will try different model

# %%
#AUTOENCODING
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

encoder_input = tf.keras.layers.Input((300, 128, 1))
x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu')(encoder_input)
x = layers.MaxPooling2D(2)(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu')(x)
x = layers.MaxPooling2D(2)(x)
x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu')(x)
x = layers.MaxPooling2D(2)(x)
x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, strides=1, padding='same', activation='relu')(x)
encoder_output = layers.GlobalMaxPooling2D()(x)

encoder = keras.Model(encoder_input, encoder_output, name="encoder")
encoder.summary()

decoder_input = keras.Input(shape=(256,), name="encoded_img")
x = tf.keras.layers.Dense(units=18*12*256, activation=tf.nn.relu)(decoder_input)
x = layers.Reshape((18, 12, 256))(x)
x = layers.Conv2DTranspose(256, 3, strides=(2,1), activation="relu")(x)
#x = layers.UpSampling2D((2, 1))(x)
x = layers.Conv2DTranspose(128, 3, strides=(2,1), activation="relu")(x)
#x = layers.UpSampling2D((2, 1))(x)
x = layers.Conv2DTranspose(128, 3, strides=(1,2), padding='same' , activation="relu")(x)
#x = layers.UpSampling2D((1, 2))(x)
x = layers.Conv2DTranspose(64, 3, strides=2, padding='same' , activation="relu")(x)
#x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2DTranspose(32, 3, strides=2, padding='same' , activation="relu")(x)
#x = layers.UpSampling2D((2, 2))(x)
decoder_output = layers.Conv2DTranspose(1, 3, strides=1, padding='same')(x)

x = layers.Conv2DTranspose(256, 3, padding='same' ,activation="relu")(x)

decoder = keras.Model(decoder_input, decoder_output, name="decoder")
decoder.summary()


autoencoder_input = keras.Input(shape=(300, 128, 1), name="img")
encoded_img = encoder(autoencoder_input)
decoded_img = decoder(encoded_img)
autoencoder = keras.Model(autoencoder_input, decoded_img, name="autoencoder")
autoencoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 300, 128, 1)]     0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 300, 128, 32)      320
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 150, 64, 32)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 150, 64, 64)       18496
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 75, 32, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 75, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 37, 16, 128)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 37, 16, 128)       147584
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 37, 16, 256)       295168
# _________________________________________________________________
# global_max_pooling2d_7 (Glob (None, 256)               0
# =================================================================
# Total params: 535,424
# Trainable params: 535,424
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_img (InputLayer)     [(None, 256)]             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 55296)             14211072
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 18, 12, 256)       0
# _________________________________________________________________
# conv2d_transpose_35 (Conv2DT (None, 37, 14, 256)       590080
# _________________________________________________________________
# conv2d_transpose_36 (Conv2DT (None, 75, 16, 128)       295040
# _________________________________________________________________
# conv2d_transpose_37 (Conv2DT (None, 75, 32, 128)       147584
# _________________________________________________________________
# conv2d_transpose_38 (Conv2DT (None, 150, 64, 64)       73792
# _________________________________________________________________
# conv2d_transpose_39 (Conv2DT (None, 300, 128, 32)      18464
# _________________________________________________________________
# conv2d_transpose_40 (Conv2DT (None, 300, 128, 1)       289
# =================================================================
# Total params: 15,336,321
# Trainable params: 15,336,321
# Non-trainable params: 0
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             [(None, 300, 128, 1)]     0
# _________________________________________________________________
# encoder (Functional)         (None, 256)               535424
# _________________________________________________________________
# decoder (Functional)         (None, 300, 128, 1)       15336321
# =================================================================
# Total params: 15,871,745
# Trainable params: 15,871,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer=Adam(), loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()])

# %%
history = autoencoder.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 37/37 [==============================] - 41s 171ms/step - loss: 1120.0069 - mean_squared_error: 1120.0068 - val_loss: 138.0791 - val_mean_squared_error: 138.0791
# Epoch 2/50
# 37/37 [==============================] - 5s 131ms/step - loss: 142.4351 - mean_squared_error: 142.4351 - val_loss: 114.7826 - val_mean_squared_error: 114.7826
# Epoch 3/50
# 37/37 [==============================] - 5s 133ms/step - loss: 119.1976 - mean_squared_error: 119.1976 - val_loss: 119.0599 - val_mean_squared_error: 119.0599
# Epoch 4/50
# 37/37 [==============================] - 5s 133ms/step - loss: 142.6444 - mean_squared_error: 142.6444 - val_loss: 114.9920 - val_mean_squared_error: 114.9920
# Epoch 5/50
# 37/37 [==============================] - 5s 134ms/step - loss: 114.8265 - mean_squared_error: 114.8265 - val_loss: 112.0857 - val_mean_squared_error: 112.0857
# Epoch 6/50
# 37/37 [==============================] - 5s 133ms/step - loss: 122.0775 - mean_squared_error: 122.0775 - val_loss: 110.9353 - val_mean_squared_error: 110.9353
# Epoch 7/50
# 37/37 [==============================] - 5s 133ms/step - loss: 107.9655 - mean_squared_error: 107.9655 - val_loss: 127.3796 - val_mean_squared_error: 127.3797
# Epoch 8/50
# 37/37 [==============================] - 5s 133ms/step - loss: 123.7379 - mean_squared_error: 123.7379 - val_loss: 100.4029 - val_mean_squared_error: 100.4029
# Epoch 9/50
# 37/37 [==============================] - 5s 132ms/step - loss: 107.4520 - mean_squared_error: 107.4520 - val_loss: 100.0053 - val_mean_squared_error: 100.0053
# Epoch 10/50
# 37/37 [==============================] - 5s 131ms/step - loss: 110.3653 - mean_squared_error: 110.3653 - val_loss: 97.1406 - val_mean_squared_error: 97.1406
# Epoch 11/50
# 37/37 [==============================] - 5s 131ms/step - loss: 108.4913 - mean_squared_error: 108.4913 - val_loss: 97.2936 - val_mean_squared_error: 97.2936
# Epoch 12/50
# 37/37 [==============================] - 5s 131ms/step - loss: 109.8085 - mean_squared_error: 109.8085 - val_loss: 106.3539 - val_mean_squared_error: 106.3539
# Epoch 13/50
# 37/37 [==============================] - 5s 131ms/step - loss: 112.1436 - mean_squared_error: 112.1436 - val_loss: 160.5302 - val_mean_squared_error: 160.5301
# Epoch 14/50
# 37/37 [==============================] - 5s 131ms/step - loss: 126.4224 - mean_squared_error: 126.4224 - val_loss: 97.1443 - val_mean_squared_error: 97.1443
# Epoch 15/50
# 37/37 [==============================] - 5s 131ms/step - loss: 105.1245 - mean_squared_error: 105.1245 - val_loss: 121.3122 - val_mean_squared_error: 121.3122
# Epoch 16/50
# 37/37 [==============================] - 5s 131ms/step - loss: 127.0750 - mean_squared_error: 127.0749 - val_loss: 110.1585 - val_mean_squared_error: 110.1585
# Epoch 17/50
# 37/37 [==============================] - 5s 131ms/step - loss: 112.2390 - mean_squared_error: 112.2390 - val_loss: 96.0211 - val_mean_squared_error: 96.0211
# Epoch 18/50
# 37/37 [==============================] - 5s 132ms/step - loss: 99.7905 - mean_squared_error: 99.7905 - val_loss: 95.9038 - val_mean_squared_error: 95.9038
# Epoch 19/50
# 37/37 [==============================] - 5s 132ms/step - loss: 103.3030 - mean_squared_error: 103.3030 - val_loss: 96.0724 - val_mean_squared_error: 96.0724
# Epoch 20/50
# 37/37 [==============================] - 5s 132ms/step - loss: 100.5401 - mean_squared_error: 100.5401 - val_loss: 97.2149 - val_mean_squared_error: 97.2149
# Epoch 21/50
# 37/37 [==============================] - 5s 132ms/step - loss: 99.1252 - mean_squared_error: 99.1252 - val_loss: 100.6830 - val_mean_squared_error: 100.6830
# Epoch 22/50
# 37/37 [==============================] - 5s 132ms/step - loss: 99.6813 - mean_squared_error: 99.6813 - val_loss: 97.3722 - val_mean_squared_error: 97.3722
# Epoch 23/50
# 37/37 [==============================] - 5s 133ms/step - loss: 101.7205 - mean_squared_error: 101.7205 - val_loss: 95.8112 - val_mean_squared_error: 95.8112
# Epoch 24/50
# 37/37 [==============================] - 5s 132ms/step - loss: 97.1558 - mean_squared_error: 97.1558 - val_loss: 97.7290 - val_mean_squared_error: 97.7290
# Epoch 25/50
# 37/37 [==============================] - 5s 132ms/step - loss: 92.1706 - mean_squared_error: 92.1706 - val_loss: 102.1721 - val_mean_squared_error: 102.1721
# Epoch 26/50
# 37/37 [==============================] - 5s 132ms/step - loss: 91.7856 - mean_squared_error: 91.7856 - val_loss: 117.5847 - val_mean_squared_error: 117.5847
# Epoch 27/50
# 37/37 [==============================] - 5s 132ms/step - loss: 95.4666 - mean_squared_error: 95.4666 - val_loss: 101.5470 - val_mean_squared_error: 101.5470
# Epoch 28/50
# 37/37 [==============================] - 5s 132ms/step - loss: 89.2903 - mean_squared_error: 89.2903 - val_loss: 96.4000 - val_mean_squared_error: 96.4000
# Epoch 29/50
# 37/37 [==============================] - 5s 132ms/step - loss: 88.1897 - mean_squared_error: 88.1897 - val_loss: 100.0091 - val_mean_squared_error: 100.0091
# Epoch 30/50
# 37/37 [==============================] - 5s 132ms/step - loss: 88.9043 - mean_squared_error: 88.9043 - val_loss: 99.6272 - val_mean_squared_error: 99.6272
# Epoch 31/50
# 37/37 [==============================] - 5s 132ms/step - loss: 97.9294 - mean_squared_error: 97.9294 - val_loss: 114.1230 - val_mean_squared_error: 114.1230
# Epoch 32/50
# 37/37 [==============================] - 5s 132ms/step - loss: 100.5093 - mean_squared_error: 100.5093 - val_loss: 99.8038 - val_mean_squared_error: 99.8038
# Epoch 33/50
# 37/37 [==============================] - 5s 131ms/step - loss: 84.5528 - mean_squared_error: 84.5528 - val_loss: 98.1852 - val_mean_squared_error: 98.1852
# Epoch 34/50
# 37/37 [==============================] - 5s 132ms/step - loss: 83.3008 - mean_squared_error: 83.3008 - val_loss: 100.9660 - val_mean_squared_error: 100.9660
# Epoch 35/50
# 37/37 [==============================] - 5s 132ms/step - loss: 86.2391 - mean_squared_error: 86.2391 - val_loss: 100.0768 - val_mean_squared_error: 100.0768
# Epoch 36/50
# 37/37 [==============================] - 5s 132ms/step - loss: 82.5782 - mean_squared_error: 82.5782 - val_loss: 99.2839 - val_mean_squared_error: 99.2839
# Epoch 37/50
# 37/37 [==============================] - 5s 132ms/step - loss: 82.8160 - mean_squared_error: 82.8160 - val_loss: 101.0254 - val_mean_squared_error: 101.0254
# Epoch 38/50
# 37/37 [==============================] - 5s 132ms/step - loss: 81.0692 - mean_squared_error: 81.0692 - val_loss: 100.4846 - val_mean_squared_error: 100.4847
# Epoch 39/50
# 37/37 [==============================] - 5s 131ms/step - loss: 79.9337 - mean_squared_error: 79.9337 - val_loss: 99.5450 - val_mean_squared_error: 99.5450
# Epoch 40/50
# 37/37 [==============================] - 5s 132ms/step - loss: 78.1159 - mean_squared_error: 78.1159 - val_loss: 98.0003 - val_mean_squared_error: 98.0004
# Epoch 41/50
# 37/37 [==============================] - 5s 132ms/step - loss: 78.8586 - mean_squared_error: 78.8586 - val_loss: 103.1445 - val_mean_squared_error: 103.1445
# Epoch 42/50
# 37/37 [==============================] - 5s 132ms/step - loss: 77.8043 - mean_squared_error: 77.8043 - val_loss: 100.6283 - val_mean_squared_error: 100.6283
# Epoch 43/50
# 37/37 [==============================] - 5s 132ms/step - loss: 79.7592 - mean_squared_error: 79.7592 - val_loss: 101.0057 - val_mean_squared_error: 101.0057
# Epoch 44/50
# 37/37 [==============================] - 5s 133ms/step - loss: 79.6414 - mean_squared_error: 79.6413 - val_loss: 109.3067 - val_mean_squared_error: 109.3067
# Epoch 45/50
# 37/37 [==============================] - 5s 132ms/step - loss: 83.3215 - mean_squared_error: 83.3215 - val_loss: 100.5627 - val_mean_squared_error: 100.5627
# Epoch 46/50
# 37/37 [==============================] - 5s 132ms/step - loss: 83.5810 - mean_squared_error: 83.5810 - val_loss: 105.4366 - val_mean_squared_error: 105.4366
# Epoch 47/50
# 37/37 [==============================] - 5s 132ms/step - loss: 77.4962 - mean_squared_error: 77.4962 - val_loss: 100.4731 - val_mean_squared_error: 100.4731
# Epoch 48/50
# 37/37 [==============================] - 5s 132ms/step - loss: 76.6908 - mean_squared_error: 76.6908 - val_loss: 100.3775 - val_mean_squared_error: 100.3775
# Epoch 49/50
# 37/37 [==============================] - 5s 132ms/step - loss: 76.2008 - mean_squared_error: 76.2008 - val_loss: 99.9296 - val_mean_squared_error: 99.9296
# Epoch 50/50
# 37/37 [==============================] - 5s 132ms/step - loss: 76.0223 - mean_squared_error: 76.0223 - val_loss: 98.8885 - val_mean_squared_error: 98.8885

# %%
import matplotlib.pyplot as plt

Epochs = 50
train_loss = history.history['loss']
train_accuracy = history.history['val_loss']

epochs = range(Epochs)

plt.figure()
plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, train_accuracy, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([70, 200])
plt.legend()
plt.show()

# %%
pred_mask = autoencoder.predict(X_test)
pred_mask = pred_mask.reshape(144,300,128)
y_test = y_test.reshape(144,300,128)

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display

fig, ax = plt.subplots(2)
a = librosa.display.specshow(y_test[0], y_axis='mel', fmax=8000, x_axis='time', ax=ax[0])
fig.colorbar(a, format='%+2.0f dB', ax=ax[0])
ax[0].set_title('test')
#ax[0].show()

b = librosa.display.specshow(pred_mask[0], y_axis='mel', fmax=8000, x_axis='time', ax=ax[1])
fig.colorbar(b, format='%+2.0f dB', ax=ax[1])
ax[1].set_title('Predicted')
#ax[1].show()
# Out:
# Text(0.5, 1.0, 'Predicted')

# %%
import scipy
from scipy.io.wavfile import write
import numpy as np


sr=22050

#First Approach audio conversion
audio_path = '/content/audio/test.wav'
wav = librosa.db_to_power(y_test[0], ref=1.0)
wav = librosa.feature.inverse.mel_to_audio (M=wav, hop_length=512, sr=sr)
#wav *= 32767 / max (0.01, np.max(np.abs(wav)))
#scipy.io.wavfile.write (audio_path, 16000, wav.astype(np.int16))
write (audio_path, sr, wav.astype(np.float32))

sr=22050

#First Approach audio conversion
audio_path = '/content/audio/predicted.wav'
wav = librosa.db_to_power(pred_mask[0], ref=1.0)
wav = librosa.feature.inverse.mel_to_audio (M=wav, hop_length=512, sr=sr)
#wav *= 32767 / max (0.01, np.max(np.abs(wav)))
#scipy.io.wavfile.write (audio_path, 16000, wav.astype(np.int16))
write (audio_path, sr, wav.astype(np.float32))

# %%
import matplotlib.pyplot as plt
y, sr = librosa.load('/content/audio/test.wav')
fig, ax = plt.subplots(nrows=2, sharex=True, sharey=True)
librosa.display.waveplot(y, sr=sr, ax=ax[0])
ax[0].set(title='Original Audio file')
ax[0].label_outer()

y, sr = librosa.load('/content/audio/predicted.wav')
librosa.display.waveplot(y, sr=sr, ax=ax[1])
ax[1].set(title='Predicted Audio')
ax[1].label_outer()
